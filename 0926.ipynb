# %%
#1
a = '''長庚大學
醫學系
郭乃綺'''
print(a)
# Out:
# 長庚大學
# 醫學系
# 郭乃綺

# %%
#2
b = input('輸入一個數字：')
print(bool(float(b)>10))
# Out:
# 輸入一個數字：6
# False

# %%
#3
a=3;b=5
print(a**b)
# Out:
# 243

# %%
#4
a=3;b=5
print(a!=b)
# Out:
# True

# %%
#5
a=3;b=5
print(a/b)
a/=b
print(a)
# Out:
# 0.6
# 0.6
